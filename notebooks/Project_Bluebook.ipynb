# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
provider_tsv = 'data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017 (1).tsv'
providers = pd.read_csv(provider_tsv, sep='\t',low_memory=False)
providers.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                    ARDALAN                            NaN
# 2                    ARDALAN                            NaN
# 3                    ARDALAN                            NaN
# 4                    ARDALAN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# ...

# %%
outpatient_csv = 'data/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017.csv'
outpatient = pd.read_csv(outpatient_csv)
outpatient.head()
# Out:
#    Provider_ID                     Provider_Name Provider_Street_Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider_City Provider_State  Provider_Zip_Code Provider_HRR   APC  \
# 0        Dothan             AL              36301  AL - Dothan  5072
# 1        Dothan             AL              36301  AL - Dothan  5073
# 2        Dothan             AL              36301  AL - Dothan  5091
# 3        Dothan             AL              36301  AL - Dothan  5092
# 4        Dothan             AL              36301  AL - Dothan  5112
#
#                                             APC_Desc  Beneficiaries  \
# ...

# %%
classification_excel = 'data/2020_january_web_addendum_b.12312019.xlsx'
classifications = pd.read_excel(classification_excel)
classifications.head()
# Out:
#    Unnamed: 0 Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020  \
# 0         NaN  CPT codes and descriptions only are copyright ...
# 1  HCPCS Code                                   Short Descriptor
# 2       00100                              Anesth salivary gland
# 3       00102                         Anesth repair of cleft lip
# 4       00103                              Anesth blepharoplasty
#
#   Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0        NaN        NaN              NaN            NaN
# 1         SI       APC   Relative Weight  Payment Rate
# 2          N        NaN              NaN            NaN
# 3          N        NaN              NaN            NaN
# 4          N        NaN              NaN            NaN
#
#                        Unnamed: 6                     Unnamed: 7  \
# 0                             NaN                            NaN
# 1  National Unadjusted Copayment   Minimum Unadjusted Copayment
# ...

# %%
cbsa_excel = 'data/ZIP_CBSA_032020.xlsx'
cbsa = pd.read_excel(cbsa_excel)
cbsa.head()
# Out:
#    ZIP   CBSA  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0  501  35620        0.0        1.0        0.0        1.0
# 1  601  38660        1.0        1.0        1.0        1.0
# 2  602  10380        1.0        1.0        1.0        1.0
# 3  603  10380        1.0        1.0        1.0        1.0
# 4  604  10380        1.0        1.0        1.0        1.0

# %%
# column names contain newline characters, remove them
# also convert spaces to underscores and make lowercase
outpatient.columns = outpatient.columns.str.replace('\n', '_').str.replace(' ', '_').str.lower()
providers.columns = providers.columns.str.replace(' ', '_').str.lower()
classifications.columns = classifications.columns.str.replace(' ', '_').str.lower()
cbsa.columns = cbsa.columns.str.replace(' ', '_').str.lower()

# %%
providers.head()
# Out:
#    national_provider_identifier last_name/organization_name_of_the_provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   first_name_of_the_provider middle_initial_of_the_provider  \
# 0                    ARDALAN                            NaN
# 1                    ARDALAN                            NaN
# 2                    ARDALAN                            NaN
# 3                    ARDALAN                            NaN
# 4                    ARDALAN                            NaN
#
#   credentials_of_the_provider gender_of_the_provider  \
# 0                        M.D.                      M
# ...

# %%
tennessee_providers= providers[(providers['state_code_of_the_provider']=='TN')]
tennessee_providers.head(5)
# Out:
#      national_provider_identifier last_name/organization_name_of_the_provider  \
# 415                    1003002254                                WALGREEN CO.
# 416                    1003002254                                WALGREEN CO.
# 417                    1003002254                                WALGREEN CO.
# 418                    1003002254                                WALGREEN CO.
# 419                    1003002254                                WALGREEN CO.
#
#     first_name_of_the_provider middle_initial_of_the_provider  \
# 415                        NaN                            NaN
# 416                        NaN                            NaN
# 417                        NaN                            NaN
# 418                        NaN                            NaN
# 419                        NaN                            NaN
#
#     credentials_of_the_provider gender_of_the_provider  \
# 415                         NaN                    NaN
# ...

# %%
#tennessee_providers_cities = tennessee_providers[(tennessee_providers.nppes_provider_city=='NASHVILLE')|
#(tennessee_providers.nppes_provider_city=='FRANKLIN')|(tennessee_providers.nppes_provider_city=='HENDERSONVILLE')
#(tennessee_providers.nppes_provider_city=='MURFREESBORO')]



tennessee_providers_cities = tennessee_providers[(tennessee_providers['city_of_the_provider']=='NASHVILLE')|
(tennessee_providers['city_of_the_provider']=='FRANKLIN')|(tennessee_providers['city_of_the_provider']=='HENDERSONVILLE')|
(tennessee_providers['city_of_the_provider']=='MURFREESBORO')|(tennessee_providers['city_of_the_provider']=='LEBANON')]


tennessee_providers_cities
# Out:
#          national_provider_identifier  \
# 2395                       1003013947
# 2396                       1003013947
# 2397                       1003013947
# 2398                       1003013947
# 2399                       1003013947
# 2400                       1003013947
# 2401                       1003013947
# 2402                       1003013947
# 2403                       1003013947
# 2404                       1003013947
# 2405                       1003013947
# 2406                       1003013947
# 3848                       1003019902
# 3849                       1003019902
# 3850                       1003019902
# 3851                       1003019902
# 3852                       1003019902
# 5740                       1003031261
# 5741                       1003031261
# 5742                       1003031261
# 5743                       1003031261
# 5744                       1003031261
# 5745                       1003031261
# ...

# %%
outpatient.head(5)
# Out:
#    provider_id                     provider_name provider_street_address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   provider_city provider_state  provider_zip_code provider_hrr   apc  \
# 0        Dothan             AL              36301  AL - Dothan  5072
# 1        Dothan             AL              36301  AL - Dothan  5073
# 2        Dothan             AL              36301  AL - Dothan  5091
# 3        Dothan             AL              36301  AL - Dothan  5092
# 4        Dothan             AL              36301  AL - Dothan  5112
#
#                                             apc_desc  beneficiaries  \
# ...

# %%
tennessee_outpatient_providers=outpatient[(outpatient['provider_state']=='TN')]
tennessee_outpatient_providers.head(5)
# Out:
#        provider_id                            provider_name  \
# 49863       440001          Unicoi County Memorial Hospital
# 49864       440002  Jackson-Madison County General Hospital
# 49865       440002  Jackson-Madison County General Hospital
# 49866       440002  Jackson-Madison County General Hospital
# 49867       440002  Jackson-Madison County General Hospital
#
#       provider_street_address provider_city provider_state  provider_zip_code  \
# 49863         Greenway Circle         Erwin             TN              37650
# 49864       620 Skyline Drive       Jackson             TN              38301
# 49865       620 Skyline Drive       Jackson             TN              38301
# 49866       620 Skyline Drive       Jackson             TN              38301
# 49867       620 Skyline Drive       Jackson             TN              38301
#
#             provider_hrr   apc  \
# 49863  TN - Johnson City  8011
# 49864       TN - Jackson  5072
# 49865       TN - Jackson  5073
# ...

# %%
#tennessee_outpatient_cities = tennessee_outpatient[(tennessee_outpatient.provider_city=='Nashville')|
#(tennessee_outpatient.provider_city=='Hendersonville')|(tennessee_outpatient.provider_city=='Franklin')|
#(tennessee_outpatient.provider_city=='Murfreesboro')]



tennessee_outpatient_provider_city = tennessee_outpatient_providers[(tennessee_outpatient_providers['provider_city']=='Nashville')|
                                                (tennessee_outpatient_providers['provider_city']=='Hendersonville')|
                                                (tennessee_outpatient_providers['provider_city']=='Franklin')|
                                                (tennessee_outpatient_providers['provider_city']=='Murfreesboro')|
                                                (tennessee_outpatient_providers['provider_city']=='Lebanon')]
tennessee_outpatient_provider_city.head(5)
# Out:
#        provider_id                   provider_name provider_street_address  \
# 49925       440006  Tristar Skyline Medical Center     3441 Dickerson Pike
# 49926       440006  Tristar Skyline Medical Center     3441 Dickerson Pike
# 49927       440006  Tristar Skyline Medical Center     3441 Dickerson Pike
# 49928       440006  Tristar Skyline Medical Center     3441 Dickerson Pike
# 49929       440006  Tristar Skyline Medical Center     3441 Dickerson Pike
#
#       provider_city provider_state  provider_zip_code    provider_hrr   apc  \
# 49925     Nashville             TN              37207  TN - Nashville  5072
# 49926     Nashville             TN              37207  TN - Nashville  5073
# 49927     Nashville             TN              37207  TN - Nashville  5091
# 49928     Nashville             TN              37207  TN - Nashville  5092
# 49929     Nashville             TN              37207  TN - Nashville  5112
#
# ...

# %%
mid_tn_providers = tennessee_providers_cities.drop(columns=['middle_initial_of_the_provider','state_code_of_the_provider',
                                                              'country_code_of_the_provider','gender_of_the_provider',
                                                              'medicare_participation_indicator','street_address_2_of_the_provider'])

# %%
mid_tn_providers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54115 entries, 2395 to 9846018
# Data columns (total 20 columns):
# national_provider_identifier                                54115 non-null int64
# last_name/organization_name_of_the_provider                 54115 non-null object
# first_name_of_the_provider                                  51922 non-null object
# credentials_of_the_provider                                 50653 non-null object
# entity_type_of_the_provider                                 54115 non-null object
# street_address_1_of_the_provider                            54115 non-null object
# city_of_the_provider                                        54115 non-null object
# zip_code_of_the_provider                                    54115 non-null object
# provider_type                                               54115 non-null object
# place_of_service                                            54115 non-null object
# ...

# %%
# individual statements for filters
mid_tn_providers_43249 = mid_tn_providers.loc[
    (mid_tn_providers['entity_type_of_the_provider'] == 'O') &
    (mid_tn_providers['provider_type'] == 'Ambulatory Surgical Center')
   & (mid_tn_providers['hcpcs_code'] == '43249')
]

# %%
mid_tn_providers_43249
# Out:
#          national_provider_identifier  \
# 1272942                    1124498357
# 2185063                    1225039761
# 6277101                    1639299803
#
#         last_name/organization_name_of_the_provider  \
# 1272942       ENDOSCOPY CENTER OF INLAND EMPIRE LLC
# 2185063            ENDOSCOPY CENTER OF ST THOMAS LP
# 6277101             MURFREESBORO MEDICAL CLINIC P A
#
#         first_name_of_the_provider credentials_of_the_provider  \
# 1272942                        NaN                         NaN
# 2185063                        NaN                         NaN
# 6277101                        NaN                         NaN
#
#         entity_type_of_the_provider street_address_1_of_the_provider  \
# 1272942                           O                  401 COMMERCE ST
# 2185063                           O                  4230 HARDING RD
# 6277101                           O                 1272 GARRISON DR
#
#         city_of_the_provider zip_code_of_the_provider  \
# ...

# %%
# individual statements for filters
tennessee_outpatient_provider_city_5302 = tennessee_outpatient_provider_city.loc[
    tennessee_outpatient_provider_city['apc'] == 5302
]


tennessee_outpatient_provider_city_5302
# Out:
#        provider_id                          provider_name  \
# 49936       440006         Tristar Skyline Medical Center
# 50148       440029              Williamson Medical Center
# 50271       440039   Vanderbilt University Medical Center
# 50429       440053       Saint Thomas Rutherford Hospital
# 50662       440082             Saint Thomas West Hospital
# 50793       440111       Metro Nashville General Hospital
# 50927       440133          Saint Thomas Midtown Hospital
# 51057       440161      Tristar Centennial Medical Center
# 51257       440193             Tennova Healthcare-Lebanon
# 51275       440194  Tristar Hendersonville Medical Center
# 51289       440197  Tristar Southern Hills Medical Center
#
#            provider_street_address   provider_city provider_state  \
# 49936          3441 Dickerson Pike       Nashville             TN
# 50148       4321 Carothers Parkway        Franklin             TN
# 50271    1211 Medical Center Drive       Nashville             TN
# ...
